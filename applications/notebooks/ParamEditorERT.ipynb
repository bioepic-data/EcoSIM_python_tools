# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path


from scripts.ParamEditor import ParEditor

#how to 
parfile='/Users/jinyuntang/work/github/ecosim_workspace/croots/input_data/ecosim_pftpar_20260520.nc'
parfile='/Users/jinyuntang/work/github/bgc_book/pftpar_SOAP.nc';
parEditor=ParEditor(pftparfile=parfile)
parEditor.reset(True)
#parfile='/Users/jinyuntang/work/github/ecosim_benchmark/smallset/Blodget'
#pft='gr3s43'

#to_remove = ["gr3s43", "gr3s43    "]
#parEditor.delete_pft_records(parfile, "ecosim_filtered.nc", to_remove)


#parEditor.CopyPlantPft(pft_from='gr3s32',pft_to='gr3s43')
pft='ndlf35'
pars={'ISNTYP':4}
parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)

pft='gr3s35'
pars={'ISNTYP':1}
parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)

pft='woat35'
pars={'ISNTYP':1}
parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)

pft='shru35'
pars={'ISNTYP':2}
parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
# Out:
# Old jsonl files are removed.
# /Users/jinyuntang/work/github/bgc_book/pftpar_SOAP.nc
# /Users/jinyuntang/work/github/bgc_book/pftpar_SOAP.nc
# /Users/jinyuntang/work/github/bgc_book/pftpar_SOAP.nc
# /Users/jinyuntang/work/github/bgc_book/pftpar_SOAP.nc

# %%
#parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
#ParamModify(parfile,pft,parnm,0.8)
parfile='/Users/jinyuntang/work/github/ecosim_workspace/croots/input_data/ecosim_pftpar_20260520.nc'
parEditor=ParEditor(pftparfile=parfile)
parEditor.reset(True)

pft='ndlf43'
pars={'RUBP':0.20,'CHL':0.20,'CNWL':2.7,'CPWL':27,'CNWR':2.35,'CPWR':23.5,
      'RRAD1M':5.e-4,'RRAD2M':2.5e-4,'PORT':0.01,'WDLF':10,'ANGBR':90,'ANGSH':0,
      'VCMX':30,'VOMX':15,'ETMX':300,'PTSHT':1.e-2,'SLA1':4.e-3,'OSMO':-1.5,
      'RSRA':4.e9,'RSRR':5000,'RTFQ':200,'SDMX':75,'GRMX':0.07,'GRDM':0.04,'STMX':0.1,
      'UPMXZH':4e-3,'UPKMZH':0.5,'UPMXZO':2e-2,'UPKMZO':2,'UPMXPO':0.5e-3,'XKCO2':12,'XKO2':450,'SNL1':0.25,
      'CFI':0.75,'RSMX':3500,'PB':0.25,'FCO2':0.7,'ROOTMAGE':1500,'R95MAT':5e-2,'ZTYPI':1,'ISNTYP':4}

parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
pft='gr3s43'
pars={'ZTYPI':1.0,'CHL':0.20,'RUBP':0.35,'ETMX':500,'SLA1':0.005,'UPMXZO':0.05,'UPMXZH':0.06,'UPKMZH':10,'UPKMZO':25,'VCMX':40,'CFI':0.9,
      'RSRA':5.e8,'RSRR':2000,'RTFQ':400,'PTSHT':0.6e-2,'XDL':14.5,'RCS':0.2,'IGTYP':1,'CNWL':2.8,'CPWL':42.,'CNWR':2.3,'CPWR':28.0,'OSMO':-1.25,'ISNTYP':1,
     'FCO2':0.7,'RRAD2M':0.1e-3,'RRAD1M':0.3e-3,'GRMX':2.5e-3,'GRDM':1.e-3,'PORT':0.15,'WDLF':5,'ANGSH':75,'CTC':-10,'PhiMEAN':0.05,'SNL1':0.4,'IEBTYP':3}
parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
# Out:
# Old jsonl files are removed.
# /Users/jinyuntang/work/github/ecosim_workspace/croots/input_data/ecosim_pftpar_20260520.nc
# axial root resistivity                                                                              : RSRA for ndlf43 is 141388896.0, and changed to 4000000000.0
# radial root resistivity                                                                             : RSRR for ndlf43 is 27777.77734375, and changed to 5000
# /Users/jinyuntang/work/github/ecosim_workspace/croots/input_data/ecosim_pftpar_20260520.nc
# axial root resistivity                                                                              : RSRA for gr3s43 is 50000000.0, and changed to 500000000.0
# radial root resistivity                                                                             : RSRR for gr3s43 is 10000.0, and changed to 2000
