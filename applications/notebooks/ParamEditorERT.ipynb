# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path


from scripts.ParamEditor import ParEditor

#how to 
parfile='/Users/jinyuntang/work/github/ecosim_workspace/benchmark/code/input_data/ecosim_pftpar_20260303.nc'
parEditor=ParEditor(pftparfile=parfile)
parEditor.reset(True)
#parfile='/Users/jinyuntang/work/github/ecosim_benchmark/smallset/Blodget'
#pft='gr3s43'

#to_remove = ["gr3s43", "gr3s43    "]
#parEditor.delete_pft_records(parfile, "ecosim_filtered.nc", to_remove)


#parEditor.CopyPlantPft(pft_from='gr3s32',pft_to='gr3s43')
# Out:
# Old jsonl files are removed.

# %%
#parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
#ParamModify(parfile,pft,parnm,0.8)
pft='ndlf43'
pars={'RUBP':0.20,'CHL':0.20,'CNWL':2.7,'CPWL':27,'CNWR':2.35,'CPWR':23.5,
      'RRAD1M':5.e-4,'RRAD2M':2.5e-4,'PORT':0.02,'WDLF':10,'ANGBR':90,'ANGSH':45,
      'VCMX':30,'VOMX':15,'ETMX':300,'PTSHT':8.e-3,'SLA1':4.e-3,'OSMO':-1.5,
      'RSRA':5.09e11/3600.,'RSRR':1e8/3600,'RTFQ':400,'SDMX':75,'GRMX':0.07,'GRDM':0.04,'STMX':0.1,
      'UPMXZH':4e-3,'UPKMZH':0.5,'UPMXZO':2e-2,'UPKMZO':2,'UPMXPO':0.5e-3,'XKCO2':12,'XKO2':450,'SNL1':0.1,
      'CFI':0.75,'RSMX':3500,'PB':0.25,'FCO2':0.7,'ROOTMAGE':1500,'R95MAT':5e-2,'ZTYPI':1,'ISNTYP':4}

parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
pft='gr3s43'
pars={'ZTYPI':1.0,'CHL':0.20,'RUBP':0.35,'ETMX':500,'SLA1':0.005,'UPMXZO':0.5,'UPMXZH':0.6,'UPKMZH':10,'UPKMZO':25,'VCMX':80,'CFI':0.9,
      'RSRA':50000000,'RSRR':10000,'RTFQ':1000,'PTSHT':3.e-3,'RCS':0.2,'IGTYP':1,'CNWL':2.8,'CPWL':42.,'CNWR':2.3,'CPWR':28.0,'OSMO':-1.25,'ISNTYP':1,
     'FCO2':0.7,'RRAD2M':0.1e-3,'RRAD1M':0.3e-3,'GRMX':2.5e-3,'GRDM':1.e-3,'PORT':0.1,'WDLF':5,'ANGSH':75,'CTC':-10,'PhiMEAN':0.05,'SNL1':0.8}
parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
# Out:
# /Users/jinyuntang/work/github/ecosim_workspace/benchmark/code/input_data/ecosim_pftpar_20260303.nc
# /Users/jinyuntang/work/github/ecosim_workspace/benchmark/code/input_data/ecosim_pftpar_20260303.nc
