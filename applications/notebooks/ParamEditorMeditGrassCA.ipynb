# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path


from scripts.ParamEditor import ParEditor

#how to 
parfile='/Users/jinyuntang/work/github/ecosim_workspace/croots/input_data/ecosim_pftpar_20260520.nc'
micparfile='/Users/jinyuntang/work/github/ecosim_workspace/croots/input_data/MicrobePars.20260211.nc'
parEditor=ParEditor(pftparfile=parfile,micparfile=micparfile)
parEditor.CopyPlantPft('clva35','clva34')
# Out:
# /Users/jinyuntang/work/github/ecosim_workspace/croots/input_data/ecosim_pftpar_20260520.nc
# /Users/jinyuntang/work/github/ecosim_workspace/croots/input_data/ecosim_pftpar_20260520.nc

# %%
#how to 
pft='gr3a34'
pars = {'ANGBR': 80,'ANGSH': 70,'CFI': 0.8,'CHL': 0.16,'CLASS':[0.10,0.20,0.35,0.35],'CNWL': 2.5,'CNWR': 2.16,'CPWL': 35.0,'CPWR': 28.0,'DMGR':0.85,
        'ETMX': 800,'FCO2':0.7,'GRDM': 0.009,'GROUPX': 4,'IEBTYP':3,'OSMO': -2.5,'PB': 0.2,'PhiMEAN': 0.2,'PORT': 0.05,'PTSHT': 0.005,
        'RRAD1M': 0.15e-3,'RRAD2M': 0.05e-3,'RSRA': 200000000.0,'RSRR': 10000.0,'RTFQ': 400,'RUBP': 0.25,'SLA1': 0.003,'SNL1': 0.8,'SSL1': 0.4,
        'STMX':100,'UPKMZH': 20.0,'UPKMZO': 70.0,'UPMXZH': 0.01,'UPMXZO': 0.05,'VCMX': 50,'VOMX': 13,'VRNLI': 72,'VRNXI': 220,'WDLF': 25,
        'XPPD': 4,'XRLA': 0.015,'XRNI': 0.008,'XTLI': 2.5,'ZTYPI': 2.5}

parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)

print('')
pft='clva34'
pars = {'ANGBR': 60,'ANGSH': 45,'CHL': 0.20,'CLASS':[0.45,0.35,0.15,0.05],'CNWL': 2.5,'CNWR': 2.15,'CPWL': 30.0,'CPWR': 26.0,'DMGR':0.55,
        'ETMX': 500,'FCO2': 0.7,'GRDM': 0.0008,'GROUPX': 3,'IEBTYP':4,'IGTYP': 1,'INTYP':1,'OSMO': -1.8,'PB': 0.2,'PORT': 0.03,'PTSHT': 0.005,
        'PhiMEAN': 0.25,'RRAD1M': 0.4e-3,'RRAD2M': 0.1e-3,'RSRA': 2000000000.0,'RSRR': 20000.0,'RTFQ': 400,'RUBP': 0.3,'SLA1': 0.0025,
        'SNL1': 0.2,'SSL1': 1.2,'STMX':25,'UPKMZH': 50.0,'UPKMZO': 120.0,'UPMXZH': 0.005,'UPMXZO': 0.01,'VCMX': 45,'VOMX': 12,'VRNLI': 170,
        'VRNXI': 220,'WDLF': 1.2,'XPPD': 3.5,'XRLA': 0.015,'XRNI': 0.015,'XTLI': 1.5,'ZTYPI': 2.5}
parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
# Out:
# /Users/jinyuntang/work/github/ecosim_workspace/croots/input_data/ecosim_pftpar_20260520.nc
# stem angle from horizontal                                                                          : ANGBR for gr3a34 is 90.0, and changed to 80
# petiole angle from horizontal                                                                       : ANGSH for gr3a34 is 90.0, and changed to 70
# initial clumping factor                                                                             : CFI for gr3a34 is 1.0, and changed to 0.8
# Fraction of leaf protein binded with chlorophyll                                                    : CHL for gr3a34 is 0.02500000037252903, and changed to 0.16
# fraction of leaf area in 0-22.5,45,67.5,90o inclination classes                                     : CLASS for gr3a34 is [0.  0.  0.5 0.5], and changed to [0.1, 0.2, 0.35, 0.35]
# Protein C to leaf N ratio in plant leaves                                                           : CNWL for gr3a34 is 2.5999999046325684, and changed to 2.5
# Protein C to root N ratio in plant roots                                                            : CNWR for gr3a34 is 2.1500000953674316, and changed to 2.16
# Protein C to leaf P ratio in plant leaves                                                           : CPWL for gr3a34 is 28.399999618530273, and changed to 35.0
# Protein C to root P ratio in plant roots                                                            : CPWR for gr3a34 is 40.0, and changed to 28.0
# grain C production vs nonstructural C consumption                                                   : DMGR for gr3a34 is 0.8799999952316284, and changed to 0.85
# specific chlorophyll activity                                                                       : ETMX for gr3a34 is 405.0, and changed to 800
# seed C mass at planting                                                                             : GRDM for gr3a34 is 0.019999999552965164, and changed to 0.009
# initial plant maturity group, aka minimum number of vegetative nodes initiated before floral        : GROUPX for gr3a34 is 6.0, and changed to 4
# Embrophyte type                                                                                     : IEBTYP for gr3a34 is 1, and changed to 3
# leaf osmotic potential at zero leaf water potential                                                 : OSMO for gr3a34 is -1.25, and changed to -2.5
# the mean fraction found in the root as lumen for non-tree roots                                     : PhiMEAN for gr3a34 is 0.009999999776482582, and changed to 0.2
# root porosity                                                                                       : PORT for gr3a34 is 0.20000000298023224, and changed to 0.05
# rate constant for equilibrating shoot-root nonstructural C concentration                            : PTSHT for gr3a34 is 0.05000000074505806, and changed to 0.005
# radius of primary root tips                                                                         : RRAD1M for gr3a34 is 0.00019999999494757503, and changed to 0.00015
# radius of secondary roots                                                                           : RRAD2M for gr3a34 is 9.999999747378752e-05, and changed to 5e-05
# axial root resistivity                                                                              : RSRA for gr3a34 is 400000000.0, and changed to 200000000.0
# root branching frequency                                                                            : RTFQ for gr3a34 is 250.0, and changed to 400
# fraction of leaf protein in rubisco                                                                 : RUBP for gr3a34 is 0.125, and changed to 0.25
# growth in leaf area vs mass                                                                         : SLA1 for gr3a34 is 0.003329999977722764, and changed to 0.003
# growth in internode stalk length vs mass                                                            : SNL1 for gr3a34 is 0.15000000596046448, and changed to 0.8
# growth in petiole length vs mass                                                                    : SSL1 for gr3a34 is 0.125, and changed to 0.4
# maximum potential seed sites for pre-anthesis stalk growth                                          : STMX for gr3a34 is 7.5, and changed to 100
# NH4 uptake Km                                                                                       : UPKMZH for gr3a34 is 0.4000000059604645, and changed to 20.0
# NO3 uptake Km                                                                                       : UPKMZO for gr3a34 is 0.3499999940395355, and changed to 70.0
# NH4 max uptake                                                                                      : UPMXZH for gr3a34 is 0.02500000037252903, and changed to 0.01
# NO3 max uptake                                                                                      : UPMXZO for gr3a34 is 0.02500000037252903, and changed to 0.05
# specific C3 rubisco carboxylase                                                                     : VCMX for gr3a34 is 45.0, and changed to 50
# specific rubisco oxygenase activity                                                                 : VOMX for gr3a34 is 9.5, and changed to 13
# hour requirement for spring leafout                                                                 : VRNLI for gr3a34 is 480.0, and changed to 72
# hour requirement for autumn leafoff                                                                 : VRNXI for gr3a34 is 720.0, and changed to 220
# leaf length vs width ratio                                                                          : WDLF for gr3a34 is 15.0, and changed to 25
# rate of leaf appearance at 25oC                                                                     : XRLA for gr3a34 is 0.008999999612569809, and changed to 0.015
# rate of node initiation at 25oC                                                                     : XRNI for gr3a34 is 0.014999999664723873, and changed to 0.008
# node number in seed at planting                                                                     : XTLI for gr3a34 is 3.0, and changed to 2.5
# thermal adaptation zone                                                                             : ZTYPI for gr3a34 is 2.0, and changed to 2.5
#
# /Users/jinyuntang/work/github/ecosim_workspace/croots/input_data/ecosim_pftpar_20260520.nc
# Fraction of leaf protein binded with chlorophyll                                                    : CHL for clva34 is 0.15000000596046448, and changed to 0.2
# fraction of leaf area in 0-22.5,45,67.5,90o inclination classes                                     : CLASS for clva34 is [0.25 0.25 0.25 0.25], and changed to [0.45, 0.35, 0.15, 0.05]
# grain C production vs nonstructural C consumption                                                   : DMGR for clva34 is 0.8799999952316284, and changed to 0.55
# specific chlorophyll activity                                                                       : ETMX for clva34 is 400.0, and changed to 500
# seed C mass at planting                                                                             : GRDM for clva34 is 0.006000000052154064, and changed to 0.0008
# initial plant maturity group, aka minimum number of vegetative nodes initiated before floral        : GROUPX for clva34 is 6.0, and changed to 3
# Embrophyte type                                                                                     : IEBTYP for clva34 is 1, and changed to 4
# N2 fixation                                                                                         : INTYP for clva34 is 2, and changed to 1
# root porosity                                                                                       : PORT for clva34 is 0.10000000149011612, and changed to 0.03
# rate constant for equilibrating shoot-root nonstructural C concentration                            : PTSHT for clva34 is 0.03999999910593033, and changed to 0.005
# radius of primary root tips                                                                         : RRAD1M for clva34 is 0.004000000189989805, and changed to 0.0004
# radius of secondary roots                                                                           : RRAD2M for clva34 is 0.0001500000071246177, and changed to 0.0001
# axial root resistivity                                                                              : RSRA for clva34 is 200000000.0, and changed to 2000000000.0
# root branching frequency                                                                            : RTFQ for clva34 is 250.0, and changed to 400
# growth in leaf area vs mass                                                                         : SLA1 for clva34 is 0.003000000026077032, and changed to 0.0025
# growth in internode stalk length vs mass                                                            : SNL1 for clva34 is 0.15000000596046448, and changed to 0.2
# growth in petiole length vs mass                                                                    : SSL1 for clva34 is 0.125, and changed to 1.2
# maximum potential seed sites for pre-anthesis stalk growth                                          : STMX for clva34 is 7.5, and changed to 25
# NH4 uptake Km                                                                                       : UPKMZH for clva34 is 20.0, and changed to 50.0
# NO3 uptake Km                                                                                       : UPKMZO for clva34 is 50.0, and changed to 120.0
# NH4 max uptake                                                                                      : UPMXZH for clva34 is 0.004000000189989805, and changed to 0.005
# NO3 max uptake                                                                                      : UPMXZO for clva34 is 0.004999999888241291, and changed to 0.01
# specific C3 rubisco carboxylase                                                                     : VCMX for clva34 is 22.0, and changed to 45
# hour requirement for spring leafout                                                                 : VRNLI for clva34 is 480.0, and changed to 170
# hour requirement for autumn leafoff                                                                 : VRNXI for clva34 is 480.0, and changed to 220
# leaf length vs width ratio                                                                          : WDLF for clva34 is 1.100000023841858, and changed to 1.2
# photoperiod sensitivity, i.e. difference between current and critical daylengths used to calculate  phenological progress: XPPD for clva34 is 4.0, and changed to 3.5
# rate of leaf appearance at 25oC                                                                     : XRLA for clva34 is 0.008999999612569809, and changed to 0.015
# node number in seed at planting                                                                     : XTLI for clva34 is 3.0, and changed to 1.5
# thermal adaptation zone                                                                             : ZTYPI for clva34 is 2.0, and changed to 2.5
