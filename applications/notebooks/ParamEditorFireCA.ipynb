# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path


from scripts.ParamEditor import ParEditor

#how to 
parfile='/Users/jinyuntang/work/github/ecosim_workspace/croots/input_data/ecosim_pftpar_20260520.nc'
micparfile='/Users/jinyuntang/work/github/ecosim_workspace/Stdead/input_data/MicrobePars.20260211.nc'
parEditor=ParEditor(pftparfile=parfile,micparfile=micparfile)
#parEditor.CopyPlantPft('clva35','clva34')

# %%
#how to 
pft='gr3a35'
pars = {'ZTYPI': 2.5,'I2EXP':0,'ISNTYP':1,'IEBTYP':3}

parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)

pft='ndlf35'
pars={'RUBP':0.20,'CHL':0.20,'CNWL':2.7,'CPWL':27,'CNWR':2.35,'CPWR':23.5,
      'RRAD1M':5.e-4,'RRAD2M':2.5e-4,'PORT':0.02,'WDLF':10,'ANGBR':90,'ANGSH':45,
      'VCMX':50,'VOMX':15,'ETMX':400,'PTSHT':1.e-2,'SLA1':4.e-3,'OSMO':-1.5,'SNL1':0.01,
      'RSRA':5.09e11/3600.,'RSRR':1e8/3600,'RTFQ':400,'SDMX':75,'GRMX':0.07,'GRDM':0.04,'STMX':0.1,
      'UPMXZH':4e-3,'UPKMZH':0.5,'UPMXZO':2e-2,'UPKMZO':2,'UPMXPO':0.5e-3,'XKCO2':12,'XKO2':450,
      'CFI':0.75,'RSMX':3500,'PB':0.25,'FCO2':0.7,'ROOTMAGE':1500,'R95MAT':5e-2,'ZTYPI':2.5,
     'I2EXP':1,'ISNTYP':4}

parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
# Out:
# /Users/jinyuntang/work/github/ecosim_workspace/croots/input_data/ecosim_pftpar_20260520.nc
# /Users/jinyuntang/work/github/ecosim_workspace/croots/input_data/ecosim_pftpar_20260520.nc
# growth in internode stalk length vs mass                                                            : SNL1 for ndlf35 is 0.029999999329447746, and changed to 0.01

# %%
print(4.7228742550156877-4.6053665841431775 -0.11806141001234632         )
# Out:
# -0.0005537391398360847

# %%
print(5.9341126722580180     -   1.3287460881148405)
# Out:
# 4.6053665841431775

# %%
print(4.7228742550156868 -4.6053665841431775         )
# Out:
# 0.11750767087250935
