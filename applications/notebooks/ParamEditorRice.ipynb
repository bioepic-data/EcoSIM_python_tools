# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path


from scripts.ParamEditor import ParEditor

#how to 
parfile='/Users/jinyuntang/work/github/ecosim_workspace/croots/input_data/ecosim_pftpar_20260520.nc'
micparfile='/Users/jinyuntang/work/github/ecosim_workspace/croots/input_data/MicrobePars.20260211.nc'
parEditor=ParEditor(pftparfile=parfile,micparfile=micparfile)

# %%
#how to 

pft='rice34'
pftvars={'ETMX':600,'SLA1':0.006,'PORT':0.2,'VCMX':60,'RTFQ':600,'CHL':0.17,'RUBP':0.3,'GROUPX':9,'TAUR':0.1,'FCO2':0.7,'UPMXZH':0.5,
         'ZTYPI':2.5,'UPMXZO':0.5,'RCS':0.125,'PhiMEAN':0.04,'RRAD1M':0.3e-3,'RRAD2M':0.05e-3,'RSRR':5e7/3600,'RSRA':2.7e9/3600,
        'GRW2L':0.4,'IEBTYP':3,'ISNTYP':1}
parEditor.PlantParamModify(pft,pftvars,iscale=False,verbose=True)
#micpars={'VMXCH4gH2':0.8,'VMXCH4gAcet':0.8,'VMXF':0.9};
#parEditor.MicrobeParamModify(micpars,iscale=True)
# Out:
# /Users/jinyuntang/work/github/ecosim_workspace/croots/input_data/ecosim_pftpar_20260520.nc
