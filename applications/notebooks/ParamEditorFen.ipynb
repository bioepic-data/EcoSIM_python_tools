# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path


from scripts.ParamEditor import ParEditor

#how to 
parfile='/Users/jinyuntang/work/github/ecosim_workspace/CanSnow/input_data/ecosim_pftpar_20260303.nc'
micparfile='/Users/jinyuntang/work/github/ecosim_workspace/CanSnow/input_data/MicrobePars.20260211.nc'
parEditor=ParEditor(pftparfile=parfile,micparfile=micparfile)

# %%
#how to 

pft='sedg62'
pftvars={'RUBP':0.2,'CHL':0.20,'CNWL':2.48,'CPWL':28.,'CNWR':2.18,'CPWR':34.6,'FCO2':0.7,'RRAD1M':2e-4,'RRAD2M':0.5e-4,
         'PORT':0.4,'GRMX':4.5E-4,'GRDM':4.0e-4,'SDMX':250,'STMX':0.1,'WDLF':5.,'ANGBR':90,'ANGSH':70,'ETMX':300,
         'VCMX':35,'VOMX':10,'SLA1':0.003,'ALBP':0.075,'IEBTYP':3,'PTSHT':0.01,'VRNXI':720,'GROUPX':6.0,'XRNI':0.015,'RTFQ':1200,'ZTYPI':1.0,
         'PB':0.1,'VRNLI':40,'CTC':-10,'RSRR':1.e4,'RSRA':1.e8,'OSMO':-1.8,'PhiMEAN':0.03,'I2EXP':0,'ISNTYP':1,
        'UPMXZH':0.06,'UPKMZH':5.0,'UPMXZO':0.03,'UPKMZO':25.,'XKCO2':14,'XKO2':500}

parEditor.PlantParamModify(pft,pftvars,iscale=False,verbose=True)
micpars={'VMXCH4gH2':0.125*0.4,'VMXCH4gAcet':0.125*0.4,'VMXF':0.125*0.4};
parEditor.MicrobeParamModify(micpars,iscale=False)
# Out:
# /Users/jinyuntang/work/github/ecosim_workspace/CanSnow/input_data/ecosim_pftpar_20260303.nc
# /Users/jinyuntang/work/github/ecosim_workspace/CanSnow/input_data/MicrobePars.20260211.nc

# %%
print(0.125**2)
# Out:
# 0.015625
